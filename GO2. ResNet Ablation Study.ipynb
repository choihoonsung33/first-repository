# %% [markdown]
# **Improt**

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds

# %% [markdown]
# **Plain Networks**
#
# 1) Conv block

# %%
def conv_batch(layer, channel, kernel_size, padding='same', strides=1, activation='relu', name='0'):
    x = keras.layers.Conv2D(filters=channel,
                            kernel_size=kernel_size,
                            kernel_initializer='he_normal',
                            kernel_regularizer=keras.regularizers.l2(1e-4),
                            padding=padding,
                            strides=strides,
                            name=f'conv_{name}')(layer)
    x = keras.layers.BatchNormalization(name=f'batch_{name}')(x)
    if activation:
        x = keras.layers.Activation(activation, name=f'act_{name}')(x)
    
    return x

# %% [markdown]
# 2) Plain block

# %%
def build_plain_block(input_layer, block_num=0, num_cnn=3, channel=64, is_50=True):
    x = input_layer
    
    # plain_50
    if is_50:
        for i in range(num_cnn):
            if block_num > 0 and i==0:
                x = conv_batch(x, channel, (1,1), strides=2, name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}2')
                x = conv_batch(x, channel*4, (1,1), name=f'{block_num}_{i}3')
            else:
                x = conv_batch(x, channel, (1,1), name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}2')
                x = conv_batch(x, channel*4, (1,1), name=f'{block_num}_{i}3')
    # plain_34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i==0:
                x = conv_batch(x, channel, (3,3), strides=2, name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}2')
            else:
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}2')

    return x

# %% [markdown]
# 3) Build plain network

# %%
 def build_plain(num_cnn_list, channel_list, is_50=True, cats_vs_dogs=False, input_shape=(32,32,3), num_classes=10, name='Plain_50'):
    
    assert len(num_cnn_list) == len(channel_list)
    
    input_layer = keras.layers.Input(shape=input_shape, name='Input')
    
    # first layer
    conv1 = conv_batch(input_layer, 64, (7,7), strides=2, name='first')
    plain = keras.layers.MaxPool2D(pool_size=(2,2), strides=2, name='maxpool_first')(conv1)
    
    # plain block
    for block_num, (cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        plain = build_plain_block(plain, block_num, cnn, channel, is_50)
    
    gap = keras.layers.GlobalAveragePooling2D(name='GAP')(plain)
    
    if cats_vs_dogs:
        output = keras.layers.Dense(1, activation='sigmoid',kernel_initializer='he_normal', name='FC')(gap)
    else:
        output = keras.layers.Dense(num_classes, activation='softmax',kernel_initializer='he_normal', name='FC')(gap)
    
    model = keras.Model(inputs=input_layer, outputs=output, name=name)
    
    return model

# %% [markdown]
# 4) Plain-34

# %%
plain_34 = build_plain(num_cnn_list=[3, 4, 6, 3],
                       channel_list=[64, 128, 256, 512],
                       is_50=False,
                       input_shape=(224,224,3),
                       name='Plain_34')
plain_34.summary()
# Out:
# Model: "Plain_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv_first (Conv2D)          (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_first (BatchNormalizat (None, 112, 112, 64)      256
# _________________________________________________________________
# act_first (Activation)       (None, 112, 112, 64)      0
# _________________________________________________________________
# maxpool_first (MaxPooling2D) (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_01 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_01 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_01 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_02 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_02 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_02 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_11 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_11 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_11 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_12 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_12 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_12 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_21 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_21 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_21 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_22 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_22 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_22 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_1_01 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_1_01 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_01 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_02 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_02 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_02 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_11 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_11 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_11 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_12 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_12 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_12 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_21 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_21 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_21 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_22 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_22 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_22 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_31 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_31 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_31 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_32 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_32 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_32 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_2_01 (Conv2D)           (None, 14, 14, 256)       295168
# _________________________________________________________________
# batch_2_01 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_01 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_02 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_02 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_02 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_11 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_11 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_11 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_12 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_12 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_12 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_21 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_21 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_21 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_22 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_22 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_22 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_31 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_31 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_31 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_32 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_32 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_32 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_41 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_41 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_41 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_42 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_42 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_42 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_51 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_51 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_51 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_52 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_52 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_52 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_3_01 (Conv2D)           (None, 7, 7, 512)         1180160
# _________________________________________________________________
# batch_3_01 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_01 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_02 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_02 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_02 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_11 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_11 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_11 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_12 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_12 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_12 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_21 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_21 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_21 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_22 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_22 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_22 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# GAP (GlobalAveragePooling2D) (None, 512)               0
# _________________________________________________________________
# FC (Dense)                   (None, 10)                5130
# =================================================================
# Total params: 21,138,826
# Trainable params: 21,123,594
# Non-trainable params: 15,232
# _________________________________________________________________

# %% [markdown]
# 5) Plain-50

# %%
plain_50 = build_plain(num_cnn_list = [3, 4, 6, 3],
                       channel_list=[64, 128, 256, 512],
                       is_50=True,
                       input_shape=(224,224,3))
plain_50.summary()
# Out:
# Model: "Plain_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv_first (Conv2D)          (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_first (BatchNormalizat (None, 112, 112, 64)      256
# _________________________________________________________________
# act_first (Activation)       (None, 112, 112, 64)      0
# _________________________________________________________________
# maxpool_first (MaxPooling2D) (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_01 (Conv2D)           (None, 56, 56, 64)        4160
# _________________________________________________________________
# batch_0_01 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_01 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_02 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_02 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_02 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_03 (Conv2D)           (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_0_03 (BatchNormalizati (None, 56, 56, 256)       1024
# _________________________________________________________________
# act_0_03 (Activation)        (None, 56, 56, 256)       0
# _________________________________________________________________
# conv_0_11 (Conv2D)           (None, 56, 56, 64)        16448
# _________________________________________________________________
# batch_0_11 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_11 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_12 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_12 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_12 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_13 (Conv2D)           (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_0_13 (BatchNormalizati (None, 56, 56, 256)       1024
# _________________________________________________________________
# act_0_13 (Activation)        (None, 56, 56, 256)       0
# _________________________________________________________________
# conv_0_21 (Conv2D)           (None, 56, 56, 64)        16448
# _________________________________________________________________
# batch_0_21 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_21 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_22 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_0_22 (BatchNormalizati (None, 56, 56, 64)        256
# _________________________________________________________________
# act_0_22 (Activation)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_0_23 (Conv2D)           (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_0_23 (BatchNormalizati (None, 56, 56, 256)       1024
# _________________________________________________________________
# act_0_23 (Activation)        (None, 56, 56, 256)       0
# _________________________________________________________________
# conv_1_01 (Conv2D)           (None, 28, 28, 128)       32896
# _________________________________________________________________
# batch_1_01 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_01 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_02 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_02 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_02 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_03 (Conv2D)           (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_1_03 (BatchNormalizati (None, 28, 28, 512)       2048
# _________________________________________________________________
# act_1_03 (Activation)        (None, 28, 28, 512)       0
# _________________________________________________________________
# conv_1_11 (Conv2D)           (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_1_11 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_11 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_12 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_12 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_12 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_13 (Conv2D)           (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_1_13 (BatchNormalizati (None, 28, 28, 512)       2048
# _________________________________________________________________
# act_1_13 (Activation)        (None, 28, 28, 512)       0
# _________________________________________________________________
# conv_1_21 (Conv2D)           (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_1_21 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_21 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_22 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_22 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_22 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_23 (Conv2D)           (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_1_23 (BatchNormalizati (None, 28, 28, 512)       2048
# _________________________________________________________________
# act_1_23 (Activation)        (None, 28, 28, 512)       0
# _________________________________________________________________
# conv_1_31 (Conv2D)           (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_1_31 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_31 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_32 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_1_32 (BatchNormalizati (None, 28, 28, 128)       512
# _________________________________________________________________
# act_1_32 (Activation)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_1_33 (Conv2D)           (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_1_33 (BatchNormalizati (None, 28, 28, 512)       2048
# _________________________________________________________________
# act_1_33 (Activation)        (None, 28, 28, 512)       0
# _________________________________________________________________
# conv_2_01 (Conv2D)           (None, 14, 14, 256)       131328
# _________________________________________________________________
# batch_2_01 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_01 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_02 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_02 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_02 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_03 (Conv2D)           (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_2_03 (BatchNormalizati (None, 14, 14, 1024)      4096
# _________________________________________________________________
# act_2_03 (Activation)        (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv_2_11 (Conv2D)           (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_2_11 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_11 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_12 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_12 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_12 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_13 (Conv2D)           (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_2_13 (BatchNormalizati (None, 14, 14, 1024)      4096
# _________________________________________________________________
# act_2_13 (Activation)        (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv_2_21 (Conv2D)           (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_2_21 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_21 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_22 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_22 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_22 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_23 (Conv2D)           (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_2_23 (BatchNormalizati (None, 14, 14, 1024)      4096
# _________________________________________________________________
# act_2_23 (Activation)        (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv_2_31 (Conv2D)           (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_2_31 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_31 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_32 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_32 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_32 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_33 (Conv2D)           (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_2_33 (BatchNormalizati (None, 14, 14, 1024)      4096
# _________________________________________________________________
# act_2_33 (Activation)        (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv_2_41 (Conv2D)           (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_2_41 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_41 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_42 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_42 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_42 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_43 (Conv2D)           (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_2_43 (BatchNormalizati (None, 14, 14, 1024)      4096
# _________________________________________________________________
# act_2_43 (Activation)        (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv_2_51 (Conv2D)           (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_2_51 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_51 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_52 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_2_52 (BatchNormalizati (None, 14, 14, 256)       1024
# _________________________________________________________________
# act_2_52 (Activation)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_2_53 (Conv2D)           (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_2_53 (BatchNormalizati (None, 14, 14, 1024)      4096
# _________________________________________________________________
# act_2_53 (Activation)        (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv_3_01 (Conv2D)           (None, 7, 7, 512)         524800
# _________________________________________________________________
# batch_3_01 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_01 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_02 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_02 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_02 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_03 (Conv2D)           (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_3_03 (BatchNormalizati (None, 7, 7, 2048)        8192
# _________________________________________________________________
# act_3_03 (Activation)        (None, 7, 7, 2048)        0
# _________________________________________________________________
# conv_3_11 (Conv2D)           (None, 7, 7, 512)         1049088
# _________________________________________________________________
# batch_3_11 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_11 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_12 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_12 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_12 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_13 (Conv2D)           (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_3_13 (BatchNormalizati (None, 7, 7, 2048)        8192
# _________________________________________________________________
# act_3_13 (Activation)        (None, 7, 7, 2048)        0
# _________________________________________________________________
# conv_3_21 (Conv2D)           (None, 7, 7, 512)         1049088
# _________________________________________________________________
# batch_3_21 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_21 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_22 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_3_22 (BatchNormalizati (None, 7, 7, 512)         2048
# _________________________________________________________________
# act_3_22 (Activation)        (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_3_23 (Conv2D)           (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_3_23 (BatchNormalizati (None, 7, 7, 2048)        8192
# _________________________________________________________________
# act_3_23 (Activation)        (None, 7, 7, 2048)        0
# _________________________________________________________________
# GAP (GlobalAveragePooling2D) (None, 2048)              0
# _________________________________________________________________
# FC (Dense)                   (None, 10)                20490
# =================================================================
# Total params: 20,820,106
# Trainable params: 20,774,666
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# **ResNet**
#
# 1) Residual block

# %%
def build_residual_block(input_layer, block_num=0, num_cnn=3, channel=64, is_50=True):
    x = input_layer
    
    # ResNet 50
    if is_50:
        for i in range(num_cnn):
            if i==0:
                shortcut = conv_batch(x, channel*4, (1,1), strides=2, activation=None, name=f'_shortcut_{block_num}_{i}')
                x = conv_batch(x, channel, (1,1), strides=2, name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}2')
                x = conv_batch(x, channel*4, (1,1), activation=None, name=f'{block_num}_{i}3')
            else:
                shortcut = x
                x = conv_batch(x, channel, (1,1), name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}2')
                x = conv_batch(x, channel*4, (1,1), activation=None, name=f'{block_num}_{i}3')
            
            x = keras.layers.Add(name=f'shortcut_add_{block_num}_{i}')([x, shortcut])
            x = keras.layers.Activation('relu', name=f'shortcut_act_{block_num}_{i}')(x)
    # ResNet 34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i==0:
                shortcut = conv_batch(x, channel, (1,1), strides=2, activation=None, name=f'_shortcut_{block_num}_{i}')
                x = conv_batch(x, channel, (3,3), strides=2, name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), activation=None, name=f'{block_num}_{i}2')
            else:
                shortcut = x
                x = conv_batch(x, channel, (3,3), name=f'{block_num}_{i}1')
                x = conv_batch(x, channel, (3,3), activation=None, name=f'{block_num}_{i}2')
            
            x = keras.layers.Add(name=f'shortcut_add_{block_num}_{i}')([x, shortcut])
            x = keras.layers.Activation('relu', name=f'shortcut_act_{block_num}_{i}')(x)
    

    return x

# %% [markdown]
# 2) Build ResNet

# %%
def build_resnet(num_cnn_list, channel_list, is_50=True, cats_vs_dogs=False, input_shape=(32,32,3), num_classes=10, name='ResNet_50'):
    
    assert len(num_cnn_list) == len(channel_list)
    
    input_layer = keras.layers.Input(shape=input_shape, name='Input')
    
    # first layer
    conv1 = conv_batch(input_layer, 64, (7,7), strides=2, name='first')
    res = keras.layers.MaxPool2D(pool_size=(2,2), strides=2, name='maxpool_first')(conv1)
    
    # Residual block
    for block_num, (cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        res = build_residual_block(res, block_num, cnn, channel, is_50)
        
    gap = keras.layers.GlobalAveragePooling2D(name='GAP')(res)
    if cats_vs_dogs:
        output = keras.layers.Dense(1, activation='sigmoid',kernel_initializer='he_normal', name='FC')(gap)
    else:
        output = keras.layers.Dense(num_classes, activation='softmax',kernel_initializer='he_normal', name='FC')(gap)
    
    model = keras.Model(inputs=input_layer, outputs=output, name=name)
    return model

# %% [markdown]
# 3) ResNet-34

# %%
resnet_34 = build_resnet(num_cnn_list = [3, 4, 6, 3],
                         channel_list=[64, 128, 256, 512],
                         is_50=False,
                         input_shape=(224,224,3),
                         name='ResNet_34')
resnet_34.summary()
# Out:
# Model: "ResNet_34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_first (Conv2D)             (None, 112, 112, 64) 9472        Input[0][0]
# __________________________________________________________________________________________________
# batch_first (BatchNormalization (None, 112, 112, 64) 256         conv_first[0][0]
# __________________________________________________________________________________________________
# act_first (Activation)          (None, 112, 112, 64) 0           batch_first[0][0]
# __________________________________________________________________________________________________
# maxpool_first (MaxPooling2D)    (None, 56, 56, 64)   0           act_first[0][0]
# __________________________________________________________________________________________________
# conv_0_01 (Conv2D)              (None, 56, 56, 64)   36928       maxpool_first[0][0]
# __________________________________________________________________________________________________
# batch_0_01 (BatchNormalization) (None, 56, 56, 64)   256         conv_0_01[0][0]
# __________________________________________________________________________________________________
# act_0_01 (Activation)           (None, 56, 56, 64)   0           batch_0_01[0][0]
# __________________________________________________________________________________________________
# conv_0_02 (Conv2D)              (None, 56, 56, 64)   36928       act_0_01[0][0]
# __________________________________________________________________________________________________
# batch_0_02 (BatchNormalization) (None, 56, 56, 64)   256         conv_0_02[0][0]
# __________________________________________________________________________________________________
# shortcut_add_0_0 (Add)          (None, 56, 56, 64)   0           batch_0_02[0][0]
#                                                                  maxpool_first[0][0]
# __________________________________________________________________________________________________
# shortcut_act_0_0 (Activation)   (None, 56, 56, 64)   0           shortcut_add_0_0[0][0]
# __________________________________________________________________________________________________
# conv_0_11 (Conv2D)              (None, 56, 56, 64)   36928       shortcut_act_0_0[0][0]
# __________________________________________________________________________________________________
# batch_0_11 (BatchNormalization) (None, 56, 56, 64)   256         conv_0_11[0][0]
# __________________________________________________________________________________________________
# act_0_11 (Activation)           (None, 56, 56, 64)   0           batch_0_11[0][0]
# __________________________________________________________________________________________________
# conv_0_12 (Conv2D)              (None, 56, 56, 64)   36928       act_0_11[0][0]
# __________________________________________________________________________________________________
# batch_0_12 (BatchNormalization) (None, 56, 56, 64)   256         conv_0_12[0][0]
# __________________________________________________________________________________________________
# shortcut_add_0_1 (Add)          (None, 56, 56, 64)   0           batch_0_12[0][0]
#                                                                  shortcut_act_0_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_0_1 (Activation)   (None, 56, 56, 64)   0           shortcut_add_0_1[0][0]
# __________________________________________________________________________________________________
# conv_0_21 (Conv2D)              (None, 56, 56, 64)   36928       shortcut_act_0_1[0][0]
# __________________________________________________________________________________________________
# batch_0_21 (BatchNormalization) (None, 56, 56, 64)   256         conv_0_21[0][0]
# __________________________________________________________________________________________________
# act_0_21 (Activation)           (None, 56, 56, 64)   0           batch_0_21[0][0]
# __________________________________________________________________________________________________
# conv_0_22 (Conv2D)              (None, 56, 56, 64)   36928       act_0_21[0][0]
# __________________________________________________________________________________________________
# batch_0_22 (BatchNormalization) (None, 56, 56, 64)   256         conv_0_22[0][0]
# __________________________________________________________________________________________________
# shortcut_add_0_2 (Add)          (None, 56, 56, 64)   0           batch_0_22[0][0]
#                                                                  shortcut_act_0_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_0_2 (Activation)   (None, 56, 56, 64)   0           shortcut_add_0_2[0][0]
# __________________________________________________________________________________________________
# conv_1_01 (Conv2D)              (None, 28, 28, 128)  73856       shortcut_act_0_2[0][0]
# __________________________________________________________________________________________________
# batch_1_01 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_01[0][0]
# __________________________________________________________________________________________________
# act_1_01 (Activation)           (None, 28, 28, 128)  0           batch_1_01[0][0]
# __________________________________________________________________________________________________
# conv_1_02 (Conv2D)              (None, 28, 28, 128)  147584      act_1_01[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_1_0 (Conv2D)     (None, 28, 28, 128)  8320        shortcut_act_0_2[0][0]
# __________________________________________________________________________________________________
# batch_1_02 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_02[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_1_0 (BatchNorma (None, 28, 28, 128)  512         conv__shortcut_1_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_0 (Add)          (None, 28, 28, 128)  0           batch_1_02[0][0]
#                                                                  batch__shortcut_1_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_0 (Activation)   (None, 28, 28, 128)  0           shortcut_add_1_0[0][0]
# __________________________________________________________________________________________________
# conv_1_11 (Conv2D)              (None, 28, 28, 128)  147584      shortcut_act_1_0[0][0]
# __________________________________________________________________________________________________
# batch_1_11 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_11[0][0]
# __________________________________________________________________________________________________
# act_1_11 (Activation)           (None, 28, 28, 128)  0           batch_1_11[0][0]
# __________________________________________________________________________________________________
# conv_1_12 (Conv2D)              (None, 28, 28, 128)  147584      act_1_11[0][0]
# __________________________________________________________________________________________________
# batch_1_12 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_12[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_1 (Add)          (None, 28, 28, 128)  0           batch_1_12[0][0]
#                                                                  shortcut_act_1_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_1 (Activation)   (None, 28, 28, 128)  0           shortcut_add_1_1[0][0]
# __________________________________________________________________________________________________
# conv_1_21 (Conv2D)              (None, 28, 28, 128)  147584      shortcut_act_1_1[0][0]
# __________________________________________________________________________________________________
# batch_1_21 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_21[0][0]
# __________________________________________________________________________________________________
# act_1_21 (Activation)           (None, 28, 28, 128)  0           batch_1_21[0][0]
# __________________________________________________________________________________________________
# conv_1_22 (Conv2D)              (None, 28, 28, 128)  147584      act_1_21[0][0]
# __________________________________________________________________________________________________
# batch_1_22 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_22[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_2 (Add)          (None, 28, 28, 128)  0           batch_1_22[0][0]
#                                                                  shortcut_act_1_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_2 (Activation)   (None, 28, 28, 128)  0           shortcut_add_1_2[0][0]
# __________________________________________________________________________________________________
# conv_1_31 (Conv2D)              (None, 28, 28, 128)  147584      shortcut_act_1_2[0][0]
# __________________________________________________________________________________________________
# batch_1_31 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_31[0][0]
# __________________________________________________________________________________________________
# act_1_31 (Activation)           (None, 28, 28, 128)  0           batch_1_31[0][0]
# __________________________________________________________________________________________________
# conv_1_32 (Conv2D)              (None, 28, 28, 128)  147584      act_1_31[0][0]
# __________________________________________________________________________________________________
# batch_1_32 (BatchNormalization) (None, 28, 28, 128)  512         conv_1_32[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_3 (Add)          (None, 28, 28, 128)  0           batch_1_32[0][0]
#                                                                  shortcut_act_1_2[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_3 (Activation)   (None, 28, 28, 128)  0           shortcut_add_1_3[0][0]
# __________________________________________________________________________________________________
# conv_2_01 (Conv2D)              (None, 14, 14, 256)  295168      shortcut_act_1_3[0][0]
# __________________________________________________________________________________________________
# batch_2_01 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_01[0][0]
# __________________________________________________________________________________________________
# act_2_01 (Activation)           (None, 14, 14, 256)  0           batch_2_01[0][0]
# __________________________________________________________________________________________________
# conv_2_02 (Conv2D)              (None, 14, 14, 256)  590080      act_2_01[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_2_0 (Conv2D)     (None, 14, 14, 256)  33024       shortcut_act_1_3[0][0]
# __________________________________________________________________________________________________
# batch_2_02 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_02[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_2_0 (BatchNorma (None, 14, 14, 256)  1024        conv__shortcut_2_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_0 (Add)          (None, 14, 14, 256)  0           batch_2_02[0][0]
#                                                                  batch__shortcut_2_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_0 (Activation)   (None, 14, 14, 256)  0           shortcut_add_2_0[0][0]
# __________________________________________________________________________________________________
# conv_2_11 (Conv2D)              (None, 14, 14, 256)  590080      shortcut_act_2_0[0][0]
# __________________________________________________________________________________________________
# batch_2_11 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_11[0][0]
# __________________________________________________________________________________________________
# act_2_11 (Activation)           (None, 14, 14, 256)  0           batch_2_11[0][0]
# __________________________________________________________________________________________________
# conv_2_12 (Conv2D)              (None, 14, 14, 256)  590080      act_2_11[0][0]
# __________________________________________________________________________________________________
# batch_2_12 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_12[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_1 (Add)          (None, 14, 14, 256)  0           batch_2_12[0][0]
#                                                                  shortcut_act_2_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_1 (Activation)   (None, 14, 14, 256)  0           shortcut_add_2_1[0][0]
# __________________________________________________________________________________________________
# conv_2_21 (Conv2D)              (None, 14, 14, 256)  590080      shortcut_act_2_1[0][0]
# __________________________________________________________________________________________________
# batch_2_21 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_21[0][0]
# __________________________________________________________________________________________________
# act_2_21 (Activation)           (None, 14, 14, 256)  0           batch_2_21[0][0]
# __________________________________________________________________________________________________
# conv_2_22 (Conv2D)              (None, 14, 14, 256)  590080      act_2_21[0][0]
# __________________________________________________________________________________________________
# batch_2_22 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_22[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_2 (Add)          (None, 14, 14, 256)  0           batch_2_22[0][0]
#                                                                  shortcut_act_2_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_2 (Activation)   (None, 14, 14, 256)  0           shortcut_add_2_2[0][0]
# __________________________________________________________________________________________________
# conv_2_31 (Conv2D)              (None, 14, 14, 256)  590080      shortcut_act_2_2[0][0]
# __________________________________________________________________________________________________
# batch_2_31 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_31[0][0]
# __________________________________________________________________________________________________
# act_2_31 (Activation)           (None, 14, 14, 256)  0           batch_2_31[0][0]
# __________________________________________________________________________________________________
# conv_2_32 (Conv2D)              (None, 14, 14, 256)  590080      act_2_31[0][0]
# __________________________________________________________________________________________________
# batch_2_32 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_32[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_3 (Add)          (None, 14, 14, 256)  0           batch_2_32[0][0]
#                                                                  shortcut_act_2_2[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_3 (Activation)   (None, 14, 14, 256)  0           shortcut_add_2_3[0][0]
# __________________________________________________________________________________________________
# conv_2_41 (Conv2D)              (None, 14, 14, 256)  590080      shortcut_act_2_3[0][0]
# __________________________________________________________________________________________________
# batch_2_41 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_41[0][0]
# __________________________________________________________________________________________________
# act_2_41 (Activation)           (None, 14, 14, 256)  0           batch_2_41[0][0]
# __________________________________________________________________________________________________
# conv_2_42 (Conv2D)              (None, 14, 14, 256)  590080      act_2_41[0][0]
# __________________________________________________________________________________________________
# batch_2_42 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_42[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_4 (Add)          (None, 14, 14, 256)  0           batch_2_42[0][0]
#                                                                  shortcut_act_2_3[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_4 (Activation)   (None, 14, 14, 256)  0           shortcut_add_2_4[0][0]
# __________________________________________________________________________________________________
# conv_2_51 (Conv2D)              (None, 14, 14, 256)  590080      shortcut_act_2_4[0][0]
# __________________________________________________________________________________________________
# batch_2_51 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_51[0][0]
# __________________________________________________________________________________________________
# act_2_51 (Activation)           (None, 14, 14, 256)  0           batch_2_51[0][0]
# __________________________________________________________________________________________________
# conv_2_52 (Conv2D)              (None, 14, 14, 256)  590080      act_2_51[0][0]
# __________________________________________________________________________________________________
# batch_2_52 (BatchNormalization) (None, 14, 14, 256)  1024        conv_2_52[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_5 (Add)          (None, 14, 14, 256)  0           batch_2_52[0][0]
#                                                                  shortcut_act_2_4[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_5 (Activation)   (None, 14, 14, 256)  0           shortcut_add_2_5[0][0]
# __________________________________________________________________________________________________
# conv_3_01 (Conv2D)              (None, 7, 7, 512)    1180160     shortcut_act_2_5[0][0]
# __________________________________________________________________________________________________
# batch_3_01 (BatchNormalization) (None, 7, 7, 512)    2048        conv_3_01[0][0]
# __________________________________________________________________________________________________
# act_3_01 (Activation)           (None, 7, 7, 512)    0           batch_3_01[0][0]
# __________________________________________________________________________________________________
# conv_3_02 (Conv2D)              (None, 7, 7, 512)    2359808     act_3_01[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_3_0 (Conv2D)     (None, 7, 7, 512)    131584      shortcut_act_2_5[0][0]
# __________________________________________________________________________________________________
# batch_3_02 (BatchNormalization) (None, 7, 7, 512)    2048        conv_3_02[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_3_0 (BatchNorma (None, 7, 7, 512)    2048        conv__shortcut_3_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_3_0 (Add)          (None, 7, 7, 512)    0           batch_3_02[0][0]
#                                                                  batch__shortcut_3_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_3_0 (Activation)   (None, 7, 7, 512)    0           shortcut_add_3_0[0][0]
# __________________________________________________________________________________________________
# conv_3_11 (Conv2D)              (None, 7, 7, 512)    2359808     shortcut_act_3_0[0][0]
# __________________________________________________________________________________________________
# batch_3_11 (BatchNormalization) (None, 7, 7, 512)    2048        conv_3_11[0][0]
# __________________________________________________________________________________________________
# act_3_11 (Activation)           (None, 7, 7, 512)    0           batch_3_11[0][0]
# __________________________________________________________________________________________________
# conv_3_12 (Conv2D)              (None, 7, 7, 512)    2359808     act_3_11[0][0]
# __________________________________________________________________________________________________
# batch_3_12 (BatchNormalization) (None, 7, 7, 512)    2048        conv_3_12[0][0]
# __________________________________________________________________________________________________
# shortcut_add_3_1 (Add)          (None, 7, 7, 512)    0           batch_3_12[0][0]
#                                                                  shortcut_act_3_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_3_1 (Activation)   (None, 7, 7, 512)    0           shortcut_add_3_1[0][0]
# __________________________________________________________________________________________________
# conv_3_21 (Conv2D)              (None, 7, 7, 512)    2359808     shortcut_act_3_1[0][0]
# __________________________________________________________________________________________________
# batch_3_21 (BatchNormalization) (None, 7, 7, 512)    2048        conv_3_21[0][0]
# __________________________________________________________________________________________________
# act_3_21 (Activation)           (None, 7, 7, 512)    0           batch_3_21[0][0]
# __________________________________________________________________________________________________
# conv_3_22 (Conv2D)              (None, 7, 7, 512)    2359808     act_3_21[0][0]
# __________________________________________________________________________________________________
# batch_3_22 (BatchNormalization) (None, 7, 7, 512)    2048        conv_3_22[0][0]
# __________________________________________________________________________________________________
# shortcut_add_3_2 (Add)          (None, 7, 7, 512)    0           batch_3_22[0][0]
#                                                                  shortcut_act_3_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_3_2 (Activation)   (None, 7, 7, 512)    0           shortcut_add_3_2[0][0]
# __________________________________________________________________________________________________
# GAP (GlobalAveragePooling2D)    (None, 512)          0           shortcut_act_3_2[0][0]
# __________________________________________________________________________________________________
# FC (Dense)                      (None, 10)           5130        GAP[0][0]
# ==================================================================================================
# Total params: 21,315,338
# Trainable params: 21,298,314
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %% [markdown]
# 4) ResNet-50

# %%
resnet_50 = build_resnet(num_cnn_list = [3, 4, 6, 3],
                         channel_list=[64, 128, 256, 512],
                         is_50=True,
                         input_shape=(224,224,3))
resnet_50.summary()
# Out:
# Model: "ResNet_50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_first (Conv2D)             (None, 112, 112, 64) 9472        Input[0][0]
# __________________________________________________________________________________________________
# batch_first (BatchNormalization (None, 112, 112, 64) 256         conv_first[0][0]
# __________________________________________________________________________________________________
# act_first (Activation)          (None, 112, 112, 64) 0           batch_first[0][0]
# __________________________________________________________________________________________________
# maxpool_first (MaxPooling2D)    (None, 56, 56, 64)   0           act_first[0][0]
# __________________________________________________________________________________________________
# conv_0_01 (Conv2D)              (None, 28, 28, 64)   4160        maxpool_first[0][0]
# __________________________________________________________________________________________________
# batch_0_01 (BatchNormalization) (None, 28, 28, 64)   256         conv_0_01[0][0]
# __________________________________________________________________________________________________
# act_0_01 (Activation)           (None, 28, 28, 64)   0           batch_0_01[0][0]
# __________________________________________________________________________________________________
# conv_0_02 (Conv2D)              (None, 28, 28, 64)   36928       act_0_01[0][0]
# __________________________________________________________________________________________________
# batch_0_02 (BatchNormalization) (None, 28, 28, 64)   256         conv_0_02[0][0]
# __________________________________________________________________________________________________
# act_0_02 (Activation)           (None, 28, 28, 64)   0           batch_0_02[0][0]
# __________________________________________________________________________________________________
# conv_0_03 (Conv2D)              (None, 28, 28, 256)  16640       act_0_02[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_0_0 (Conv2D)     (None, 28, 28, 256)  16640       maxpool_first[0][0]
# __________________________________________________________________________________________________
# batch_0_03 (BatchNormalization) (None, 28, 28, 256)  1024        conv_0_03[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_0_0 (BatchNorma (None, 28, 28, 256)  1024        conv__shortcut_0_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_0_0 (Add)          (None, 28, 28, 256)  0           batch_0_03[0][0]
#                                                                  batch__shortcut_0_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_0_0 (Activation)   (None, 28, 28, 256)  0           shortcut_add_0_0[0][0]
# __________________________________________________________________________________________________
# conv_0_11 (Conv2D)              (None, 28, 28, 64)   16448       shortcut_act_0_0[0][0]
# __________________________________________________________________________________________________
# batch_0_11 (BatchNormalization) (None, 28, 28, 64)   256         conv_0_11[0][0]
# __________________________________________________________________________________________________
# act_0_11 (Activation)           (None, 28, 28, 64)   0           batch_0_11[0][0]
# __________________________________________________________________________________________________
# conv_0_12 (Conv2D)              (None, 28, 28, 64)   36928       act_0_11[0][0]
# __________________________________________________________________________________________________
# batch_0_12 (BatchNormalization) (None, 28, 28, 64)   256         conv_0_12[0][0]
# __________________________________________________________________________________________________
# act_0_12 (Activation)           (None, 28, 28, 64)   0           batch_0_12[0][0]
# __________________________________________________________________________________________________
# conv_0_13 (Conv2D)              (None, 28, 28, 256)  16640       act_0_12[0][0]
# __________________________________________________________________________________________________
# batch_0_13 (BatchNormalization) (None, 28, 28, 256)  1024        conv_0_13[0][0]
# __________________________________________________________________________________________________
# shortcut_add_0_1 (Add)          (None, 28, 28, 256)  0           batch_0_13[0][0]
#                                                                  shortcut_act_0_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_0_1 (Activation)   (None, 28, 28, 256)  0           shortcut_add_0_1[0][0]
# __________________________________________________________________________________________________
# conv_0_21 (Conv2D)              (None, 28, 28, 64)   16448       shortcut_act_0_1[0][0]
# __________________________________________________________________________________________________
# batch_0_21 (BatchNormalization) (None, 28, 28, 64)   256         conv_0_21[0][0]
# __________________________________________________________________________________________________
# act_0_21 (Activation)           (None, 28, 28, 64)   0           batch_0_21[0][0]
# __________________________________________________________________________________________________
# conv_0_22 (Conv2D)              (None, 28, 28, 64)   36928       act_0_21[0][0]
# __________________________________________________________________________________________________
# batch_0_22 (BatchNormalization) (None, 28, 28, 64)   256         conv_0_22[0][0]
# __________________________________________________________________________________________________
# act_0_22 (Activation)           (None, 28, 28, 64)   0           batch_0_22[0][0]
# __________________________________________________________________________________________________
# conv_0_23 (Conv2D)              (None, 28, 28, 256)  16640       act_0_22[0][0]
# __________________________________________________________________________________________________
# batch_0_23 (BatchNormalization) (None, 28, 28, 256)  1024        conv_0_23[0][0]
# __________________________________________________________________________________________________
# shortcut_add_0_2 (Add)          (None, 28, 28, 256)  0           batch_0_23[0][0]
#                                                                  shortcut_act_0_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_0_2 (Activation)   (None, 28, 28, 256)  0           shortcut_add_0_2[0][0]
# __________________________________________________________________________________________________
# conv_1_01 (Conv2D)              (None, 14, 14, 128)  32896       shortcut_act_0_2[0][0]
# __________________________________________________________________________________________________
# batch_1_01 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_01[0][0]
# __________________________________________________________________________________________________
# act_1_01 (Activation)           (None, 14, 14, 128)  0           batch_1_01[0][0]
# __________________________________________________________________________________________________
# conv_1_02 (Conv2D)              (None, 14, 14, 128)  147584      act_1_01[0][0]
# __________________________________________________________________________________________________
# batch_1_02 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_02[0][0]
# __________________________________________________________________________________________________
# act_1_02 (Activation)           (None, 14, 14, 128)  0           batch_1_02[0][0]
# __________________________________________________________________________________________________
# conv_1_03 (Conv2D)              (None, 14, 14, 512)  66048       act_1_02[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_1_0 (Conv2D)     (None, 14, 14, 512)  131584      shortcut_act_0_2[0][0]
# __________________________________________________________________________________________________
# batch_1_03 (BatchNormalization) (None, 14, 14, 512)  2048        conv_1_03[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_1_0 (BatchNorma (None, 14, 14, 512)  2048        conv__shortcut_1_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_0 (Add)          (None, 14, 14, 512)  0           batch_1_03[0][0]
#                                                                  batch__shortcut_1_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_0 (Activation)   (None, 14, 14, 512)  0           shortcut_add_1_0[0][0]
# __________________________________________________________________________________________________
# conv_1_11 (Conv2D)              (None, 14, 14, 128)  65664       shortcut_act_1_0[0][0]
# __________________________________________________________________________________________________
# batch_1_11 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_11[0][0]
# __________________________________________________________________________________________________
# act_1_11 (Activation)           (None, 14, 14, 128)  0           batch_1_11[0][0]
# __________________________________________________________________________________________________
# conv_1_12 (Conv2D)              (None, 14, 14, 128)  147584      act_1_11[0][0]
# __________________________________________________________________________________________________
# batch_1_12 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_12[0][0]
# __________________________________________________________________________________________________
# act_1_12 (Activation)           (None, 14, 14, 128)  0           batch_1_12[0][0]
# __________________________________________________________________________________________________
# conv_1_13 (Conv2D)              (None, 14, 14, 512)  66048       act_1_12[0][0]
# __________________________________________________________________________________________________
# batch_1_13 (BatchNormalization) (None, 14, 14, 512)  2048        conv_1_13[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_1 (Add)          (None, 14, 14, 512)  0           batch_1_13[0][0]
#                                                                  shortcut_act_1_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_1 (Activation)   (None, 14, 14, 512)  0           shortcut_add_1_1[0][0]
# __________________________________________________________________________________________________
# conv_1_21 (Conv2D)              (None, 14, 14, 128)  65664       shortcut_act_1_1[0][0]
# __________________________________________________________________________________________________
# batch_1_21 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_21[0][0]
# __________________________________________________________________________________________________
# act_1_21 (Activation)           (None, 14, 14, 128)  0           batch_1_21[0][0]
# __________________________________________________________________________________________________
# conv_1_22 (Conv2D)              (None, 14, 14, 128)  147584      act_1_21[0][0]
# __________________________________________________________________________________________________
# batch_1_22 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_22[0][0]
# __________________________________________________________________________________________________
# act_1_22 (Activation)           (None, 14, 14, 128)  0           batch_1_22[0][0]
# __________________________________________________________________________________________________
# conv_1_23 (Conv2D)              (None, 14, 14, 512)  66048       act_1_22[0][0]
# __________________________________________________________________________________________________
# batch_1_23 (BatchNormalization) (None, 14, 14, 512)  2048        conv_1_23[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_2 (Add)          (None, 14, 14, 512)  0           batch_1_23[0][0]
#                                                                  shortcut_act_1_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_2 (Activation)   (None, 14, 14, 512)  0           shortcut_add_1_2[0][0]
# __________________________________________________________________________________________________
# conv_1_31 (Conv2D)              (None, 14, 14, 128)  65664       shortcut_act_1_2[0][0]
# __________________________________________________________________________________________________
# batch_1_31 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_31[0][0]
# __________________________________________________________________________________________________
# act_1_31 (Activation)           (None, 14, 14, 128)  0           batch_1_31[0][0]
# __________________________________________________________________________________________________
# conv_1_32 (Conv2D)              (None, 14, 14, 128)  147584      act_1_31[0][0]
# __________________________________________________________________________________________________
# batch_1_32 (BatchNormalization) (None, 14, 14, 128)  512         conv_1_32[0][0]
# __________________________________________________________________________________________________
# act_1_32 (Activation)           (None, 14, 14, 128)  0           batch_1_32[0][0]
# __________________________________________________________________________________________________
# conv_1_33 (Conv2D)              (None, 14, 14, 512)  66048       act_1_32[0][0]
# __________________________________________________________________________________________________
# batch_1_33 (BatchNormalization) (None, 14, 14, 512)  2048        conv_1_33[0][0]
# __________________________________________________________________________________________________
# shortcut_add_1_3 (Add)          (None, 14, 14, 512)  0           batch_1_33[0][0]
#                                                                  shortcut_act_1_2[0][0]
# __________________________________________________________________________________________________
# shortcut_act_1_3 (Activation)   (None, 14, 14, 512)  0           shortcut_add_1_3[0][0]
# __________________________________________________________________________________________________
# conv_2_01 (Conv2D)              (None, 7, 7, 256)    131328      shortcut_act_1_3[0][0]
# __________________________________________________________________________________________________
# batch_2_01 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_01[0][0]
# __________________________________________________________________________________________________
# act_2_01 (Activation)           (None, 7, 7, 256)    0           batch_2_01[0][0]
# __________________________________________________________________________________________________
# conv_2_02 (Conv2D)              (None, 7, 7, 256)    590080      act_2_01[0][0]
# __________________________________________________________________________________________________
# batch_2_02 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_02[0][0]
# __________________________________________________________________________________________________
# act_2_02 (Activation)           (None, 7, 7, 256)    0           batch_2_02[0][0]
# __________________________________________________________________________________________________
# conv_2_03 (Conv2D)              (None, 7, 7, 1024)   263168      act_2_02[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_2_0 (Conv2D)     (None, 7, 7, 1024)   525312      shortcut_act_1_3[0][0]
# __________________________________________________________________________________________________
# batch_2_03 (BatchNormalization) (None, 7, 7, 1024)   4096        conv_2_03[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_2_0 (BatchNorma (None, 7, 7, 1024)   4096        conv__shortcut_2_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_0 (Add)          (None, 7, 7, 1024)   0           batch_2_03[0][0]
#                                                                  batch__shortcut_2_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_0 (Activation)   (None, 7, 7, 1024)   0           shortcut_add_2_0[0][0]
# __________________________________________________________________________________________________
# conv_2_11 (Conv2D)              (None, 7, 7, 256)    262400      shortcut_act_2_0[0][0]
# __________________________________________________________________________________________________
# batch_2_11 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_11[0][0]
# __________________________________________________________________________________________________
# act_2_11 (Activation)           (None, 7, 7, 256)    0           batch_2_11[0][0]
# __________________________________________________________________________________________________
# conv_2_12 (Conv2D)              (None, 7, 7, 256)    590080      act_2_11[0][0]
# __________________________________________________________________________________________________
# batch_2_12 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_12[0][0]
# __________________________________________________________________________________________________
# act_2_12 (Activation)           (None, 7, 7, 256)    0           batch_2_12[0][0]
# __________________________________________________________________________________________________
# conv_2_13 (Conv2D)              (None, 7, 7, 1024)   263168      act_2_12[0][0]
# __________________________________________________________________________________________________
# batch_2_13 (BatchNormalization) (None, 7, 7, 1024)   4096        conv_2_13[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_1 (Add)          (None, 7, 7, 1024)   0           batch_2_13[0][0]
#                                                                  shortcut_act_2_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_1 (Activation)   (None, 7, 7, 1024)   0           shortcut_add_2_1[0][0]
# __________________________________________________________________________________________________
# conv_2_21 (Conv2D)              (None, 7, 7, 256)    262400      shortcut_act_2_1[0][0]
# __________________________________________________________________________________________________
# batch_2_21 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_21[0][0]
# __________________________________________________________________________________________________
# act_2_21 (Activation)           (None, 7, 7, 256)    0           batch_2_21[0][0]
# __________________________________________________________________________________________________
# conv_2_22 (Conv2D)              (None, 7, 7, 256)    590080      act_2_21[0][0]
# __________________________________________________________________________________________________
# batch_2_22 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_22[0][0]
# __________________________________________________________________________________________________
# act_2_22 (Activation)           (None, 7, 7, 256)    0           batch_2_22[0][0]
# __________________________________________________________________________________________________
# conv_2_23 (Conv2D)              (None, 7, 7, 1024)   263168      act_2_22[0][0]
# __________________________________________________________________________________________________
# batch_2_23 (BatchNormalization) (None, 7, 7, 1024)   4096        conv_2_23[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_2 (Add)          (None, 7, 7, 1024)   0           batch_2_23[0][0]
#                                                                  shortcut_act_2_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_2 (Activation)   (None, 7, 7, 1024)   0           shortcut_add_2_2[0][0]
# __________________________________________________________________________________________________
# conv_2_31 (Conv2D)              (None, 7, 7, 256)    262400      shortcut_act_2_2[0][0]
# __________________________________________________________________________________________________
# batch_2_31 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_31[0][0]
# __________________________________________________________________________________________________
# act_2_31 (Activation)           (None, 7, 7, 256)    0           batch_2_31[0][0]
# __________________________________________________________________________________________________
# conv_2_32 (Conv2D)              (None, 7, 7, 256)    590080      act_2_31[0][0]
# __________________________________________________________________________________________________
# batch_2_32 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_32[0][0]
# __________________________________________________________________________________________________
# act_2_32 (Activation)           (None, 7, 7, 256)    0           batch_2_32[0][0]
# __________________________________________________________________________________________________
# conv_2_33 (Conv2D)              (None, 7, 7, 1024)   263168      act_2_32[0][0]
# __________________________________________________________________________________________________
# batch_2_33 (BatchNormalization) (None, 7, 7, 1024)   4096        conv_2_33[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_3 (Add)          (None, 7, 7, 1024)   0           batch_2_33[0][0]
#                                                                  shortcut_act_2_2[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_3 (Activation)   (None, 7, 7, 1024)   0           shortcut_add_2_3[0][0]
# __________________________________________________________________________________________________
# conv_2_41 (Conv2D)              (None, 7, 7, 256)    262400      shortcut_act_2_3[0][0]
# __________________________________________________________________________________________________
# batch_2_41 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_41[0][0]
# __________________________________________________________________________________________________
# act_2_41 (Activation)           (None, 7, 7, 256)    0           batch_2_41[0][0]
# __________________________________________________________________________________________________
# conv_2_42 (Conv2D)              (None, 7, 7, 256)    590080      act_2_41[0][0]
# __________________________________________________________________________________________________
# batch_2_42 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_42[0][0]
# __________________________________________________________________________________________________
# act_2_42 (Activation)           (None, 7, 7, 256)    0           batch_2_42[0][0]
# __________________________________________________________________________________________________
# conv_2_43 (Conv2D)              (None, 7, 7, 1024)   263168      act_2_42[0][0]
# __________________________________________________________________________________________________
# batch_2_43 (BatchNormalization) (None, 7, 7, 1024)   4096        conv_2_43[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_4 (Add)          (None, 7, 7, 1024)   0           batch_2_43[0][0]
#                                                                  shortcut_act_2_3[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_4 (Activation)   (None, 7, 7, 1024)   0           shortcut_add_2_4[0][0]
# __________________________________________________________________________________________________
# conv_2_51 (Conv2D)              (None, 7, 7, 256)    262400      shortcut_act_2_4[0][0]
# __________________________________________________________________________________________________
# batch_2_51 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_51[0][0]
# __________________________________________________________________________________________________
# act_2_51 (Activation)           (None, 7, 7, 256)    0           batch_2_51[0][0]
# __________________________________________________________________________________________________
# conv_2_52 (Conv2D)              (None, 7, 7, 256)    590080      act_2_51[0][0]
# __________________________________________________________________________________________________
# batch_2_52 (BatchNormalization) (None, 7, 7, 256)    1024        conv_2_52[0][0]
# __________________________________________________________________________________________________
# act_2_52 (Activation)           (None, 7, 7, 256)    0           batch_2_52[0][0]
# __________________________________________________________________________________________________
# conv_2_53 (Conv2D)              (None, 7, 7, 1024)   263168      act_2_52[0][0]
# __________________________________________________________________________________________________
# batch_2_53 (BatchNormalization) (None, 7, 7, 1024)   4096        conv_2_53[0][0]
# __________________________________________________________________________________________________
# shortcut_add_2_5 (Add)          (None, 7, 7, 1024)   0           batch_2_53[0][0]
#                                                                  shortcut_act_2_4[0][0]
# __________________________________________________________________________________________________
# shortcut_act_2_5 (Activation)   (None, 7, 7, 1024)   0           shortcut_add_2_5[0][0]
# __________________________________________________________________________________________________
# conv_3_01 (Conv2D)              (None, 4, 4, 512)    524800      shortcut_act_2_5[0][0]
# __________________________________________________________________________________________________
# batch_3_01 (BatchNormalization) (None, 4, 4, 512)    2048        conv_3_01[0][0]
# __________________________________________________________________________________________________
# act_3_01 (Activation)           (None, 4, 4, 512)    0           batch_3_01[0][0]
# __________________________________________________________________________________________________
# conv_3_02 (Conv2D)              (None, 4, 4, 512)    2359808     act_3_01[0][0]
# __________________________________________________________________________________________________
# batch_3_02 (BatchNormalization) (None, 4, 4, 512)    2048        conv_3_02[0][0]
# __________________________________________________________________________________________________
# act_3_02 (Activation)           (None, 4, 4, 512)    0           batch_3_02[0][0]
# __________________________________________________________________________________________________
# conv_3_03 (Conv2D)              (None, 4, 4, 2048)   1050624     act_3_02[0][0]
# __________________________________________________________________________________________________
# conv__shortcut_3_0 (Conv2D)     (None, 4, 4, 2048)   2099200     shortcut_act_2_5[0][0]
# __________________________________________________________________________________________________
# batch_3_03 (BatchNormalization) (None, 4, 4, 2048)   8192        conv_3_03[0][0]
# __________________________________________________________________________________________________
# batch__shortcut_3_0 (BatchNorma (None, 4, 4, 2048)   8192        conv__shortcut_3_0[0][0]
# __________________________________________________________________________________________________
# shortcut_add_3_0 (Add)          (None, 4, 4, 2048)   0           batch_3_03[0][0]
#                                                                  batch__shortcut_3_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_3_0 (Activation)   (None, 4, 4, 2048)   0           shortcut_add_3_0[0][0]
# __________________________________________________________________________________________________
# conv_3_11 (Conv2D)              (None, 4, 4, 512)    1049088     shortcut_act_3_0[0][0]
# __________________________________________________________________________________________________
# batch_3_11 (BatchNormalization) (None, 4, 4, 512)    2048        conv_3_11[0][0]
# __________________________________________________________________________________________________
# act_3_11 (Activation)           (None, 4, 4, 512)    0           batch_3_11[0][0]
# __________________________________________________________________________________________________
# conv_3_12 (Conv2D)              (None, 4, 4, 512)    2359808     act_3_11[0][0]
# __________________________________________________________________________________________________
# batch_3_12 (BatchNormalization) (None, 4, 4, 512)    2048        conv_3_12[0][0]
# __________________________________________________________________________________________________
# act_3_12 (Activation)           (None, 4, 4, 512)    0           batch_3_12[0][0]
# __________________________________________________________________________________________________
# conv_3_13 (Conv2D)              (None, 4, 4, 2048)   1050624     act_3_12[0][0]
# __________________________________________________________________________________________________
# batch_3_13 (BatchNormalization) (None, 4, 4, 2048)   8192        conv_3_13[0][0]
# __________________________________________________________________________________________________
# shortcut_add_3_1 (Add)          (None, 4, 4, 2048)   0           batch_3_13[0][0]
#                                                                  shortcut_act_3_0[0][0]
# __________________________________________________________________________________________________
# shortcut_act_3_1 (Activation)   (None, 4, 4, 2048)   0           shortcut_add_3_1[0][0]
# __________________________________________________________________________________________________
# conv_3_21 (Conv2D)              (None, 4, 4, 512)    1049088     shortcut_act_3_1[0][0]
# __________________________________________________________________________________________________
# batch_3_21 (BatchNormalization) (None, 4, 4, 512)    2048        conv_3_21[0][0]
# __________________________________________________________________________________________________
# act_3_21 (Activation)           (None, 4, 4, 512)    0           batch_3_21[0][0]
# __________________________________________________________________________________________________
# conv_3_22 (Conv2D)              (None, 4, 4, 512)    2359808     act_3_21[0][0]
# __________________________________________________________________________________________________
# batch_3_22 (BatchNormalization) (None, 4, 4, 512)    2048        conv_3_22[0][0]
# __________________________________________________________________________________________________
# act_3_22 (Activation)           (None, 4, 4, 512)    0           batch_3_22[0][0]
# __________________________________________________________________________________________________
# conv_3_23 (Conv2D)              (None, 4, 4, 2048)   1050624     act_3_22[0][0]
# __________________________________________________________________________________________________
# batch_3_23 (BatchNormalization) (None, 4, 4, 2048)   8192        conv_3_23[0][0]
# __________________________________________________________________________________________________
# shortcut_add_3_2 (Add)          (None, 4, 4, 2048)   0           batch_3_23[0][0]
#                                                                  shortcut_act_3_1[0][0]
# __________________________________________________________________________________________________
# shortcut_act_3_2 (Activation)   (None, 4, 4, 2048)   0           shortcut_add_3_2[0][0]
# __________________________________________________________________________________________________
# GAP (GlobalAveragePooling2D)    (None, 2048)         0           shortcut_act_3_2[0][0]
# __________________________________________________________________________________________________
# FC (Dense)                      (None, 10)           20490       GAP[0][0]
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# **ResNet-34 vs ResNet-50 vs Plain-34 vs Plain-50**
#
# 1) Dataset (cifar10)

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
   split=['train[:80%]', 'train[80%:]'],
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset 162.17 MiB (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /aiffel/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling cifar10-train.tfrecord...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling cifar10-test.tfrecord...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /aiffel/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
print(ds_info.features)
# Out:
# FeaturesDict({
#     'id': Text(shape=(), dtype=tf.string),
#     'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %%
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(40000, shape=(), dtype=int64)
# tf.Tensor(10000, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    image = tf.image.resize(image, (224,224)) # resize
    image = tf.cast(image, tf.float32) / 255.
    return image, label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %% [markdown]
# 2) Train

# %%
BATCH_SIZE = 32 #256
iteration = 15000 #600000
EPOCH = iteration*BATCH_SIZE//int(ds_info.splits['train'].num_examples)

# %%
EPOCH
# Out:
# 9

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
def scheduler(epoch, lr):
    if epoch == EPOCH//2:
        lr *=0.1
        print(lr)
    elif epoch == (EPOCH//4)*3:
        lr *=0.1
        print(lr)
    return lr

# %%
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.1, monitor='val_loss', patience=1, verbose=2, min_lr=1e-6)
# lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# %%
resnet_34 = build_resnet(num_cnn_list = [3, 4, 6, 3],
                         channel_list=[64, 128, 256, 512],
                         is_50=False,
                         cats_vs_dogs=True,
                         input_shape=(224,224,3),
                         name='ResNet_34')

# %%
resnet_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.1, momentum=0.9, clipnorm=1.),
    metrics=['accuracy'],
)

history_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:90%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[90%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    callbacks=[lr_scheduler],
    use_multiprocessing=True,
)
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/9
# 1406/1406 [==============================] - 315s 188ms/step - loss: -11441743.0000 - accuracy: 0.0998 - val_loss: -27444658.0000 - val_accuracy: 0.1042
# Epoch 2/9
# 1406/1406 [==============================] - 260s 185ms/step - loss: -81792048.0000 - accuracy: 0.1001 - val_loss: -104032416.0000 - val_accuracy: 0.0960
# Epoch 3/9
# 1406/1406 [==============================] - 261s 186ms/step - loss: -228147952.0000 - accuracy: 0.1006 - val_loss: -272009824.0000 - val_accuracy: 0.1016
# Epoch 4/9
# 1406/1406 [==============================] - 261s 186ms/step - loss: -455104416.0000 - accuracy: 0.0991 - val_loss: -367914048.0000 - val_accuracy: 0.1061
# Epoch 5/9
# 1406/1406 [==============================] - 261s 185ms/step - loss: -771649536.0000 - accuracy: 0.0994 - val_loss: -473728256.0000 - val_accuracy: 0.0928
# Epoch 6/9
# 1406/1406 [==============================] - 261s 185ms/step - loss: -1182204672.0000 - accuracy: 0.1003 - val_loss: -1321468928.0000 - val_accuracy: 0.1020
# Epoch 7/9
# 1406/1406 [==============================] - 261s 185ms/step - loss: -1681954816.0000 - accuracy: 0.0995 - val_loss: -2030340480.0000 - val_accuracy: 0.0969
# Epoch 8/9
# 1406/1406 [==============================] - 261s 185ms/step - loss: -2276793088.0000 - accuracy: 0.1007 - val_loss: -2955213824.0000 - val_accuracy: 0.0998
# Epoch 9/9
# 1406/1406 [==============================] - 261s 186ms/step - loss: -2973520128.0000 - accuracy: 0.0996 - val_loss: -3780316928.0000 - val_accuracy: 0.1004

# %%
resnet_50 = build_resnet(num_cnn_list = [3, 4, 6, 3],
                         channel_list=[64, 128, 256, 512],
                         is_50=True,
                         cats_vs_dogs=True,
                         input_shape=(224,224,3))

# %%
resnet_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.1, momentum=0.9, clipnorm=1.),
    metrics=['accuracy'],
)

history_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:90%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[90%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    callbacks=[lr_scheduler],
    use_multiprocessing=True,
)
# Out:
# Epoch 1/9
# 1406/1406 [==============================] - 197s 130ms/step - loss: -11216314.0000 - accuracy: 0.1000 - val_loss: -69490760.0000 - val_accuracy: 0.1006
# Epoch 2/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -80052576.0000 - accuracy: 0.1002 - val_loss: -151896096.0000 - val_accuracy: 0.1005
# Epoch 3/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -219486352.0000 - accuracy: 0.0998 - val_loss: -328990720.0000 - val_accuracy: 0.0970
# Epoch 4/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -429660128.0000 - accuracy: 0.0994 - val_loss: -406800736.0000 - val_accuracy: 0.1040
# Epoch 5/9
# 1406/1406 [==============================] - 181s 128ms/step - loss: -717320576.0000 - accuracy: 0.0992 - val_loss: -1158442112.0000 - val_accuracy: 0.1018
# Epoch 6/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -1085518848.0000 - accuracy: 0.1003 - val_loss: -1250871680.0000 - val_accuracy: 0.1004
# Epoch 7/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -1533836928.0000 - accuracy: 0.0998 - val_loss: -1979513472.0000 - val_accuracy: 0.1020
# Epoch 8/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -2070624512.0000 - accuracy: 0.1008 - val_loss: -2125703168.0000 - val_accuracy: 0.0978
# Epoch 9/9
# 1406/1406 [==============================] - 181s 129ms/step - loss: -2729093376.0000 - accuracy: 0.0998 - val_loss: -3573841920.0000 - val_accuracy: 0.0927

# %%
plain_34 = build_plain(num_cnn_list=[3, 4, 6, 3],
                       channel_list=[64, 128, 256, 512],
                       is_50=False,
                       cats_vs_dogs=True,
                       input_shape=(224,224,3),
                       name='Plain_34')

# %%
plain_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.1, momentum=0.9, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_34 = plain_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:90%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[90%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    callbacks=[lr_scheduler],
    use_multiprocessing=True,
)
# Out:
# Epoch 1/9
# 1406/1406 [==============================] - 259s 177ms/step - loss: -2771958.5000 - accuracy: 0.0997 - val_loss: -7480451.5000 - val_accuracy: 0.0968
# Epoch 2/9
# 1406/1406 [==============================] - 247s 175ms/step - loss: -19782820.0000 - accuracy: 0.1005 - val_loss: -17096648.0000 - val_accuracy: 0.0988
# Epoch 3/9
# 1406/1406 [==============================] - 247s 175ms/step - loss: -54834208.0000 - accuracy: 0.0997 - val_loss: -92124376.0000 - val_accuracy: 0.1058
# Epoch 4/9
# 1406/1406 [==============================] - 246s 175ms/step - loss: -108468840.0000 - accuracy: 0.0998 - val_loss: -121399560.0000 - val_accuracy: 0.0992
# Epoch 5/9
# 1406/1406 [==============================] - 247s 176ms/step - loss: -179463504.0000 - accuracy: 0.0997 - val_loss: -347492416.0000 - val_accuracy: 0.0958
# Epoch 6/9
# 1406/1406 [==============================] - 246s 175ms/step - loss: -269323584.0000 - accuracy: 0.1010 - val_loss: -324014976.0000 - val_accuracy: 0.1032
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.010000000149011612.
# Epoch 7/9
# 1406/1406 [==============================] - 245s 175ms/step - loss: -331058304.0000 - accuracy: 0.0986 - val_loss: -354904736.0000 - val_accuracy: 0.1036
# Epoch 8/9
# 1406/1406 [==============================] - 245s 175ms/step - loss: -342012928.0000 - accuracy: 0.1002 - val_loss: -365424672.0000 - val_accuracy: 0.1076
# Epoch 9/9
# 1406/1406 [==============================] - 246s 175ms/step - loss: -356955200.0000 - accuracy: 0.1005 - val_loss: -368840672.0000 - val_accuracy: 0.1056

# %%
plain_50 = build_plain(num_cnn_list = [3, 4, 6, 3],
                       channel_list=[64, 128, 256, 512],
                       is_50=True,
                       cats_vs_dogs=True,
                       input_shape=(224,224,3))

# %%
plain_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.1, momentum=0.9, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain_50 = plain_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:90%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[90%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    callbacks=[lr_scheduler],
    use_multiprocessing=True,
)
# Out:
# Epoch 1/9
# 1406/1406 [==============================] - 403s 276ms/step - loss: -2698083.0000 - accuracy: 0.1000 - val_loss: -7559809.5000 - val_accuracy: 0.0978
# Epoch 2/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -18993586.0000 - accuracy: 0.1005 - val_loss: -35878080.0000 - val_accuracy: 0.1010
# Epoch 3/9
# 1406/1406 [==============================] - 384s 273ms/step - loss: -51906480.0000 - accuracy: 0.0996 - val_loss: -80086536.0000 - val_accuracy: 0.1056
# Epoch 4/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -106067744.0000 - accuracy: 0.0996 - val_loss: -268290496.0000 - val_accuracy: 0.1012
# Epoch 5/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -187279920.0000 - accuracy: 0.1001 - val_loss: -481134912.0000 - val_accuracy: 0.1030
# Epoch 6/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -289183136.0000 - accuracy: 0.1007 - val_loss: -103325280.0000 - val_accuracy: 0.0976
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.010000000149011612.
# Epoch 7/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -358730240.0000 - accuracy: 0.0991 - val_loss: -301749568.0000 - val_accuracy: 0.1066
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 8/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -368526976.0000 - accuracy: 0.1003 - val_loss: -394460544.0000 - val_accuracy: 0.0964
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Epoch 9/9
# 1406/1406 [==============================] - 383s 272ms/step - loss: -369144480.0000 - accuracy: 0.0988 - val_loss: -373985696.0000 - val_accuracy: 0.1002
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.

# %% [markdown]
# 3) Comparison

# %%
plt.plot(history_34.history['val_accuracy'], 'b')
plt.plot(history_50.history['val_accuracy'], 'g')
plt.plot(history_plain_34.history['val_accuracy'], 'r')
plt.plot(history_plain_50.history['val_accuracy'], 'm')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'resnet_50', 'plain_34', 'plain_50'], loc='lower right')
plt.show()

# %% [markdown]
# **회고**
#
# ResNet-34와 ResNet-50을 구현하여, Plain-34, Plain-50과 비교해봤습니다.
# 데이터는 cifar10을 사용했습니다.
